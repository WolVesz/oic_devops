# %% [markdown]
# import sys
# import os
# sys.path.append(os.path.abspath('..'))
#
#
# from typing import Dict
# from oic_devops.client import OICClient
# from oic_devops.workflows.password_rotation import PasswordRotationWorkflow
# from oic_devops.workflows.base import BaseWorkflow, WorkflowResult
#
# import os
# import pandas as pd
# from datetime import datetime
#
# config_file = (
#     "../config.yaml"
# )
#
# # Create OIC client
# client = OICClient(profile="dev-1", config_file=config_file)
#
# # Initialize password rotation workflow
# wf = PasswordRotationWorkflow(client=client)
# self = wf
# # Call rotating the password
# target_usernames: Dict[str,str] = {"ERPIntegrationUser": "****"}
# # connection_filter = "/Psswrd/"
# connection_filter = None
# overrides = {"timeout_sec":40, "poll_interval_sec":4}
# response = wf.update_password_basic_authentication(target_usernames=target_usernames, connection_filter=connection_filter, overrides=overrides)
# #print("\n\n",response.message)

# %%
#overrides = {"timeout_sec":30, "poll_interval_sec":4}
#restore_wf = wf.restore_integrations_to_original_state(overrides = overrides)

# %%
# for detail, info in restore_wf.details.items():
#     print(detail, info)
