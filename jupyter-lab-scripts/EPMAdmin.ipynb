# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

###  Find EPMAdmin usage
from typing import Dict
from oic_devops.client import OICClient
from oic_devops.workflows.password_rotation import PasswordRotationWorkflow
from typing import Any, Dict, Iterable, List, Tuple, Optional
import pandas as pd
import os
from datetime import datetime

config_file = "C:/Users/jorher/OneDrive - Tri-State Generation and Transmission Association, Inc/Documents/GitHub/oic_devops/config.yaml"
client = OICClient(profile="prod", config_file=config_file)
wf = PasswordRotationWorkflow(client)
self = wf
wf.execute()
# Out:
# INFO:oic_devops:Initialized OIC client with profile: prod
# C:\Users\jorher\OneDrive - Tri-State Generation and Transmission Association, Inc\Documents\GitHub\oic_devops\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'idcs-e4e6a62d66af4c0897e070b2bd1d757f.identity.oraclecloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# TODO: execute() method, not implemented yet!
# WorkflowResult(success=True, message='', details={}, resources={}, errors=[])

# %%
target_usernames = {'EPMAdmin': "the love shack"} # EPMIntegrationUser  EPMAdmin
self = wf
connections_dictionary = self.build_connections_dictionary(target_usernames)
print(connections_dictionary)
for connection in connections_dictionary:
    print (connection)
    for integration_id in connections_dictionary[connection]['integrations']:
        print(f'\t{integration_id}')
# Out:
# INFO:PasswordRotationWorkflow:Building connections dictionary for usernames: ['EPMAdmin']
# INFO:PasswordRotationWorkflow:Fetching enriched connections with filter: None
# C:\Users\jorher\OneDrive - Tri-State Generation and Transmission Association, Inc\Documents\GitHub\oic_devops\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'design.integration.us-phoenix-1.ocp.oraclecloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %%
for connection in connections_dictionary:
    print (connection)
    for integration_id in connections_dictionary[connection]['integrations']:
        print(f'\t{integration_id}')
# Out:
# ORACLE_REST_EPM_CONNEC_PROJEC
# 	FTP_HCM_EPM_FILE_UPLOA_PROJE|01.00.0001
# 	FTP_PPM_EPM_FILE_UPLOAD|01.00.0001
# ORACL_REST_EPM_CONNE_FA_TAX
# 	FA_TAX_EPM_FTP|01.00.0001
# 	FA_TAX_EPM_LOC_CAT_LOAD|01.00.0001
# ORCL-BRT-REST-EPM_CONNECTION
# 	FTP_HCM_EPM_FILE_UPLOAD|01.00.0001
